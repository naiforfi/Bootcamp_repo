# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from datetime import timedelta

# %% [markdown]
# ### Loading the data in a datafram.

# %%
data = pd.read_csv('dataset/weather-sa-2017-2019-clean.csv')
data.shape
# Out:
# (249023, 15)

# %%
data.head()
# Out:
#    Unnamed: 0    city            date   time  year  month  day  hour  minute  \
# 0           0  Qassim  1 January 2017  00:00  2017      1    1    24       0
# 1           1  Qassim  1 January 2017  01:00  2017      1    1     1       0
# 2           2  Qassim  1 January 2017  03:00  2017      1    1     3       0
# 3           3  Qassim  1 January 2017  04:00  2017      1    1     4       0
# 4           4  Qassim  1 January 2017  05:00  2017      1    1     5       0
#
#   weather  temp  wind humidity  barometer  visibility
# 0  Clear     17    11      64%     1018.0          16
# 1  Clear     17     6      64%     1018.0          16
# 2  Clear     15    11      72%     1019.0          16
# 3  Clear     15    11      72%     1019.0          16
# 4  Clear     15     9      72%     1019.0          16

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  249023 non-null  int64
#  1   city        249023 non-null  object
#  2   date        249023 non-null  object
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  object
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: float64(1), int64(9), object(5)
# memory usage: 28.5+ MB

# %% [markdown]
# It show that we have one float, 9 Integers and 5 objects data types.

# %%
### Convert the data types

# %%
data['date'] = pd.to_datetime(data["date"])
data['humidity'] = pd.to_numeric(data["humidity"].str.replace('%',' '), downcast="float") / 100

# %%
data
# Out:
#         Unnamed: 0    city       date   time  year  month  day  hour  minute  \
# 0                0  Qassim 2017-01-01  00:00  2017      1    1    24       0
# 1                1  Qassim 2017-01-01  01:00  2017      1    1     1       0
# 2                2  Qassim 2017-01-01  03:00  2017      1    1     3       0
# 3                3  Qassim 2017-01-01  04:00  2017      1    1     4       0
# 4                4  Qassim 2017-01-01  05:00  2017      1    1     5       0
# ...            ...     ...        ...    ...   ...    ...  ...   ...     ...
# 249018        2848    Jawf 2019-04-30  19:00  2019      4   30    19       0
# 249019        2849    Jawf 2019-04-30  20:00  2019      4   30    20       0
# 249020        2850    Jawf 2019-04-30  21:00  2019      4   30    21       0
# 249021        2851    Jawf 2019-04-30  22:00  2019      4   30    22       0
# 249022        2852    Jawf 2019-04-30  23:00  2019      4   30    23       0
#
#                 weather  temp  wind  humidity  barometer  visibility
# 0                Clear     17    11      0.64     1018.0          16
# 1                Clear     17     6      0.64     1018.0          16
# 2                Clear     15    11      0.72     1019.0          16
# 3                Clear     15    11      0.72     1019.0          16
# 4                Clear     15     9      0.72     1019.0          16
# ...                 ...   ...   ...       ...        ...         ...
# 249018  Passing clouds     32    19      0.14     1014.0          -1
# 249019  Passing clouds     29     9      0.22     1015.0          -1
# 249020  Passing clouds     27     7      0.24     1016.0          -1
# 249021           Clear     26     0      0.26     1017.0          16
# 249022           Clear     24     7      0.29     1017.0          16
#
# [249023 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  249023 non-null  int64
#  1   city        249023 non-null  object
#  2   date        249023 non-null  datetime64[ns]
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  float32
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float32(1), float64(1), int64(9), object(3)
# memory usage: 27.5+ MB

# %% [markdown]
# ### Drop Unnecessary columns

# %% [markdown]
# Unnamed column in the index of the data and we do not need it because datafram hundle that.

# %% [markdown]
# ### Dealing with missing values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# city           0
# date           0
# time           0
# year           0
# month          0
# day            0
# hour           0
# minute         0
# weather        0
# temp           0
# wind           0
# humidity      17
# barometer     72
# visibility     0
# dtype: int64

# %%
data[data['humidity'].isnull() == True]
# Out:
#         Unnamed: 0              city       date   time  year  month  day  \
# 3385          3385            Qassim 2017-05-26  10:00  2017      5   26
# 5270          5270            Qassim 2017-08-13  04:00  2017      8   13
# 6723          6723            Qassim 2017-10-13  16:00  2017     10   13
# 23178        23178              Hail 2017-05-26  10:00  2017      5   26
# 25063        25063              Hail 2017-08-13  04:00  2017      8   13
# 26516        26516              Hail 2017-10-13  16:00  2017     10   13
# 70412        70412                EP 2018-05-10  14:00  2018      5   10
# 72357        72357                EP 2018-08-04  19:00  2018      8    4
# 72892        72892                EP 2018-08-28  04:00  2018      8   28
# 74947        74947                EP 2018-11-26  07:00  2018     11   26
# 78179        78179                EP 2019-04-21  18:00  2019      4   21
# 124812      124812             Tabuk 2018-02-13  14:00  2018      2   13
# 149566      149566  Northern boarder 2017-02-02  05:21  2017      2    2
# 229429      229429              Jawf 2017-02-01  23:36  2017      2    1
# 229454      229454              Jawf 2017-02-02  23:36  2017      2    2
# 229913      229913              Jawf 2017-02-22  06:23  2017      2   22
# 237265      237265              Jawf 2017-12-24  13:23  2017     12   24
#
#         hour  minute                       weather  temp  wind  humidity  \
# 3385      10       0                        Sunny     37     7       NaN
# 5270       4       0                        Clear     34     4       NaN
# 6723      16       0                        Sunny     38     9       NaN
# 23178     10       0                        Sunny     37     7       NaN
# 25063      4       0                        Clear     34     4       NaN
# 26516     16       0                        Sunny     38     9       NaN
# 70412     14       0                        Clear     37    26       NaN
# 72357     19       0                        Clear     36    13       NaN
# 72892      4       0                        Clear     30     7       NaN
# 74947      7       0                        Sunny     16    19       NaN
# 78179     18       0             Scattered clouds     26    19       NaN
# 124812    14       0  Thunderstorms  Partly sunny     18    30       NaN
# 149566     5      21               Passing clouds      1     7       NaN
# 229429    23      36                        Clear      5     6       NaN
# 229454    23      36                        Clear      5     6       NaN
# 229913     6      23         Rain  Passing clouds      7    11       NaN
# 237265    13      23               Low level haze     28    37       NaN
#
#         barometer  visibility
# 3385          NaN           3
# 5270          NaN          16
# 6723          NaN          16
# 23178         NaN           3
# 25063         NaN          16
# 26516         NaN          16
# 70412      1005.0          -1
# 72357       999.0          16
# 72892       997.0          16
# 74947      1017.0          16
# 78179      1003.0          -1
# 124812        NaN           9
# 149566        NaN           2
# 229429        NaN           5
# 229454        NaN           5
# 229913        NaN           6
# 237265        NaN           5

# %%
data['city'].unique()
# Out:
# array(['Qassim', 'Hail', 'Madina', 'EP', 'Riyadh', 'Mecca', 'Tabuk',
#        'Assir', 'Northern boarder', 'Jazan', 'Najran', 'Baha', 'Jawf'],
#       dtype=object)

# %%
means = (data.groupby(by='city')[['humidity']].mean()).to_dict('index')

# %%
#means
means
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fh/fd9hxlg15d74w6xz3bkb3zbr0000gn/T/ipykernel_22726/549130023.py in <module>
#       1 #means
# ----> 2 means
#
# NameError: name 'means' is not defined

# %%
  
data['humidity'] = data['humidity'].fillna(data.groupby('city')['humidity'].transform('mean'))

# %%
data.loc[3385]
# Out:
# Unnamed: 0                 149566
# city             Northern boarder
# date          2017-02-02 00:00:00
# time                        05:21
# year                         2017
# month                           2
# day                             2
# hour                            5
# minute                         21
# weather           Passing clouds
# temp                            1
# wind                            7
# humidity                 0.262638
# barometer                     NaN
# visibility                      2
# Name: 149566, dtype: object

# %%
data[data['humidity'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, city, date, time, year, month, day, hour, minute, weather, temp, wind, humidity, barometer, visibility]
# Index: []

# %%
data.isnull().sum()

# %%
#data['humidity'].fillna(data['humidity'].where(data['city'] == 'Qassim').mean()).where(data['city'] == 'Qassim')

# %%
test.shape

# %% [markdown]
# ### Weather data and create the target

# %%
data['weather'].unique()

# %%
import re
data['Rain'] = data['weather'].str.contains('rain|shower|sprinkle', case = False ,regex=True)

# %%
data['Rain'].value_counts()

# %%
data.info()
